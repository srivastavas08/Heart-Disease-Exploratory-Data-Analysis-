# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('HeartDiseaseDataset.csv')

# %%
df.shape
# Out:
# (918, 12)

# %%
df.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# ## Distribution plots for numeric data

# %%
sns.displot(df['Age'], kde = True, color = 'Red')

# %%
sns.distplot(df['Age'], hist = True)
# Out:
# /var/folders/6w/mv1nv9w5131g49jj6l9ppgbh0000gp/T/ipykernel_21725/4019601524.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], hist = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'], hist = True , rug = True)
# Out:
# /var/folders/6w/mv1nv9w5131g49jj6l9ppgbh0000gp/T/ipykernel_21725/333366002.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], hist = True , rug = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
 sns.distplot(df['Age'], hist = True , rug = True , bins = 50)
# Out:
# /var/folders/6w/mv1nv9w5131g49jj6l9ppgbh0000gp/T/ipykernel_21725/2590925080.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], hist = True , rug = True , bins = 50)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(df['RestingBP'], kde = True, color = 'Red')

# %%
 sns.distplot(df['RestingBP'], hist = True , rug = True , bins = 20)
# Out:
# /var/folders/6w/mv1nv9w5131g49jj6l9ppgbh0000gp/T/ipykernel_21725/749526473.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'], hist = True , rug = True , bins = 20)
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.displot(df['Cholesterol'], kde = True, color = 'Red')

# %%
 sns.distplot(df['Cholesterol'], hist = True , rug = True , bins = 20)
# Out:
# /var/folders/6w/mv1nv9w5131g49jj6l9ppgbh0000gp/T/ipykernel_21725/4048278722.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'], hist = True , rug = True , bins = 20)
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
 sns.distplot(df['FastingBS'], hist = True , rug = True , bins = 20)
# Out:
# /var/folders/6w/mv1nv9w5131g49jj6l9ppgbh0000gp/T/ipykernel_21725/1966988869.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['FastingBS'], hist = True , rug = True , bins = 20)
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %%
 sns.distplot(df['MaxHR'], hist = True , rug = True )
# Out:
# /var/folders/6w/mv1nv9w5131g49jj6l9ppgbh0000gp/T/ipykernel_21725/904925809.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxHR'], hist = True , rug = True )
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
 sns.distplot(df['Oldpeak'], hist = True , rug = True )
# Out:
# /var/folders/6w/mv1nv9w5131g49jj6l9ppgbh0000gp/T/ipykernel_21725/3159588498.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Oldpeak'], hist = True , rug = True )
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %% [markdown]
# ## Pie charts for categorical data

# %%
df.groupby('Sex').size().plot(kind = 'pie', autopct = '%.2f') #Autopunctuations
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie', autopct = '%.2f') #Autopunctuations
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind = 'pie', autopct = '%.2f') #Autopunctuations
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie', autopct = '%.2f') #Autopunctuations
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie', autopct = '%.2f') #Autopunctuations
# Out:
# <Axes: >

# %% [raw]
# ## For numbers and frequency bar graph is best, for categories pie is best

# %% [markdown]
# ## Violin Plots

# %% [raw]
# Violin plots are used when we want to see any corelation between two columns.
# It's a kind of distribution plot where one should be numeric and y can be categorical

# %%
 sns.violinplot(x = df['Age'], y = df['Sex'],  orient='horizontal')
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %%
 sns.violinplot(x = df['Age'], y = df['HeartDisease'],  orient='horizontal')
# Out:
# <Axes: xlabel='Age', ylabel='HeartDisease'>

# %%
 sns.violinplot(y = df['Age'], x = df['HeartDisease'], hue = df['Sex'],  orient='vertical')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
 sns.violinplot(y = df['Sex'], x = df['HeartDisease'],  orient='horizontal')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
 sns.violinplot(y = df['Cholesterol'], x = df['HeartDisease'], hue = df['Sex'],  orient='vertical')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# ## Heatmap

# %% [raw]
# Heatmap gives correlation between each columns
#
# positive relation - one increases then other also increases
# negative relation - one increases other decreases.

# %%
df.corr()
# Out:
# /var/folders/6w/mv1nv9w5131g49jj6l9ppgbh0000gp/T/ipykernel_21725/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# ...

# %%
sns.heatmap(df.corr())
# Out:
# /var/folders/6w/mv1nv9w5131g49jj6l9ppgbh0000gp/T/ipykernel_21725/58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# ## Joint Plot

# %% [raw]
# Joint Plot can be used to visualise the correlation between two columns

# %%
sns.jointplot(x = df['Age'], y = df['Age']) #age and age has 100% correlation

# %%
sns.jointplot(x = df['Age'], y = df['MaxHR'])

# %%
sns.jointplot(x = df['Age'], y = df['MaxHR'] , kind = 'hex')

# %%
sns.jointplot(x = df['Age'], y = df['MaxHR'] , kind = 'reg')

# %%
sns.jointplot(y = df['HeartDisease'], x = df['Oldpeak'], kind = 'reg')

# %% [raw]
# No correlation as heartdisease. is binary and old peak is continous value and regression line doesnt fit the data.

# %%
sns.jointplot(y = df['FastingBS'], x = df['Oldpeak'], kind = 'reg')

# %%
sns.jointplot(y = df['HeartDisease'], x = df['MaxHR'], kind = 'reg')

# %% [markdown]
# ## Pair Plot

# %% [raw]
# It shows all plots in one line

# %%
sns.pairplot(df)

# %%
sns.jointplot(x = df['Cholesterol'], y = df['MaxHR'] , kind = 'hex')

# %%
sns.jointplot(x = df['Cholesterol'], y = df['MaxHR'] , kind = 'reg')

# %% [raw]
# not very much correlated
